# %%
import matplotlib.pyplot as plt
import matplotlib

import numpy as np

# %%
# !python --version
# Out:
# Python 3.7.6

# %%
import matplotlib.patches as mpatches
from sklearn.datasets import make_blobs, make_circles

# %%
def plot_data(pl, X, y):
    pl.plot(X[y == 0, 0], X[y == 0, 1], 'ob', alpha = 0.5)
    pl.plot(X[y == 1, 0], X[y == 1, 1], 'xr', alpha = 0.5)
    pl.legend(['0', '1'])
    return pl

# %%
X, y = make_circles(n_samples = 400, factor = 0.6, noise = 0.1, random_state = 42)
pl = plot_data(plt, X, y)
pl.show()

# %%
seed = 1

print("X size = ", X.shape)
print("y size = ", y.shape)
print("Num of Samples = ", X.shape[0])
# Out:
# X size =  (400, 2)
# y size =  (400,)
# Num of Samples =  400

# %%
print(X)
# Out:
# [[ 5.22047667e-01  2.45076964e-01]
#  [-4.90174568e-01  4.04540597e-01]
#  [ 4.69901235e-01  9.04544287e-01]
#  [ 7.37010889e-01  1.11486553e-01]
#  [-9.86636209e-01  1.69521513e-01]
#  [-7.17008501e-01  4.38359514e-01]
#  [-4.41013452e-01 -5.31920699e-01]
#  [-9.95858989e-01  1.08030813e-01]
#  [-3.25897203e-01  5.41504194e-01]
#  [-6.96094447e-01 -6.45797770e-01]
#  [ 9.28358178e-01  2.58529455e-01]
#  [ 2.30348927e-01 -3.40047801e-01]
#  [-2.66141506e-01  1.17464969e+00]
#  [-7.55781307e-01  7.93410286e-01]
#  [-5.69765424e-01 -9.25855019e-01]
#  [ 3.18599125e-01  1.02857282e+00]
#  [-5.10432759e-01  1.73074993e-01]
#  [ 3.95376430e-01 -3.96807852e-01]
#  [ 3.37431388e-01  5.71841873e-01]
#  [ 7.27958177e-01 -2.31006816e-01]
#  [-6.93334233e-01  6.76130038e-01]
#  [ 1.00825010e+00  5.07130501e-01]
#  [ 6.51086779e-01  1.35010193e-02]
#  [-3.45045802e-01  4.46996781e-01]
#  [ 1.04462893e+00  1.13624232e-01]
#  [ 6.45411496e-01  3.08639177e-02]
#  [-9.71724535e-01 -5.12587714e-01]
#  [ 3.69760307e-01  2.97525839e-01]
#  [-2.09844774e-01  5.14863353e-01]
#  [-8.69093566e-01 -2.54455670e-01]
#  [ 7.48105272e-01 -1.91980713e-01]
#  [ 8.52093677e-01 -3.00608374e-01]
#  [-8.11474357e-03  5.60519948e-01]
#  [-1.65199690e-01  9.57527588e-01]
#  [ 3.12488214e-01  4.56008750e-01]
#  [-8.71232284e-01 -4.32293685e-01]
#  [-7.49924075e-01 -5.84594778e-01]
#  [ 1.18680986e-02 -5.28353854e-01]
#  [ 2.11913609e-01 -1.02335551e+00]
#  [-1.74623542e-01 -9.37395832e-01]
#  [ 3.42841833e-01 -3.00943066e-01]
#  [-4.19973115e-02  1.07347481e+00]
#  [-7.91654414e-01  5.50346376e-01]
#  [ 6.74509467e-01  1.03250529e+00]
#  [-9.98827820e-01  4.51553285e-01]
#  [ 5.45800944e-01 -3.33948602e-01]
#  [ 5.25340443e-01 -1.88833478e-01]
#  [-5.50508829e-01 -2.49539829e-01]
#  [ 1.77258331e-01  6.43331746e-01]
#  [-1.73764152e-01  9.56652283e-01]
#  [-1.84677243e-01  9.43333059e-01]
#  [ 8.00895652e-01 -8.21901847e-01]
#  [ 8.62850604e-01 -2.74718938e-01]
#  [ 6.37614008e-01  1.25213370e-02]
#  [ 8.01432572e-01 -1.40742096e-01]
#  [ 4.40508040e-01 -8.11655843e-01]
#  [-2.64555437e-01  8.49919009e-01]
#  [ 2.57695772e-02  1.00035749e+00]
#  [-1.77426110e-01 -4.95649988e-01]
#  [ 2.56231725e-01  4.00476447e-01]
#  [-1.80286865e-01  6.59432546e-01]
#  [ 6.41477934e-01  6.44549661e-01]
#  [-5.06187257e-01 -3.37824271e-01]
#  [ 3.98090803e-01 -1.12283588e+00]
#  [-4.07735283e-01  4.06642470e-01]
#  [ 9.48393888e-01 -3.96780770e-01]
#  [-6.79252258e-01  2.92766147e-01]
#  [-9.37044395e-03 -5.11341598e-01]
#  [-3.69011345e-02  6.70151412e-01]
#  [-6.13485518e-01 -1.44453577e-01]
#  [-1.78661597e-01 -1.00847612e+00]
#  [-4.69443827e-01 -8.75087719e-01]
#  [ 1.33724880e-01 -9.90347986e-01]
#  [ 2.88574771e-02 -6.86908163e-01]
#  [-9.07576273e-01  8.66631676e-02]
#  [ 3.92630801e-01 -4.89711127e-01]
#  [-8.96697828e-01  4.85177516e-01]
#  [-2.05085823e-01 -3.33041777e-01]
#  [ 5.80092222e-01  2.38274406e-01]
#  [-7.75530212e-01 -5.60695018e-01]
#  [ 6.51510631e-01  1.11952208e-01]
#  [ 1.02059257e+00  5.67259789e-01]
#  [ 1.14536498e+00 -2.50900628e-01]
#  [-6.22989353e-01  9.40011496e-01]
#  [-8.13722421e-01 -2.33410859e-01]
#  [-1.79449626e-01  5.92918479e-01]
#  [ 1.99181601e-01 -6.41219895e-01]
#  [-1.03336940e+00 -2.65456733e-01]]

# %%
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential
 
np.random.seed(seed)

model = Sequential()

# %%
model.add(Dense(1, activation = 'sigmoid', input_dim = 2))
model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')

# %%
model.fit(X, y, batch_size = 5, epochs = 100, verbose = 1)
# Out:
# Epoch 1/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.7150
# Epoch 2/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7123
# Epoch 3/100
# 80/80 [==============================] - 0s 1ms/step - loss: 0.7099
# Epoch 4/100
# 80/80 [==============================] - 0s 513us/step - loss: 0.7078
# Epoch 5/100
# 80/80 [==============================] - 0s 424us/step - loss: 0.7060
# Epoch 6/100
# 80/80 [==============================] - 0s 383us/step - loss: 0.7044
# Epoch 7/100
# 80/80 [==============================] - 0s 456us/step - loss: 0.7031
# Epoch 8/100
# 80/80 [==============================] - 0s 560us/step - loss: 0.7018
# Epoch 9/100
# 80/80 [==============================] - 0s 558us/step - loss: 0.7008
# Epoch 10/100
# 80/80 [==============================] - 0s 569us/step - loss: 0.6998
# Epoch 11/100
# 80/80 [==============================] - 0s 530us/step - loss: 0.6990
# Epoch 12/100
# 80/80 [==============================] - 0s 542us/step - loss: 0.6982
# Epoch 13/100
# 80/80 [==============================] - 0s 537us/step - loss: 0.6977
# Epoch 14/100
# 80/80 [==============================] - 0s 677us/step - loss: 0.6971
# Epoch 15/100
# 80/80 [==============================] - 0s 832us/step - loss: 0.6966
# Epoch 16/100
# 80/80 [==============================] - 0s 854us/step - loss: 0.6963
# Epoch 17/100
# 80/80 [==============================] - 0s 859us/step - loss: 0.6959
# Epoch 18/100
# 80/80 [==============================] - 0s 795us/step - loss: 0.6956
# Epoch 19/100
# 80/80 [==============================] - 0s 832us/step - loss: 0.6953
# Epoch 20/100
# 80/80 [==============================] - 0s 808us/step - loss: 0.6951
# Epoch 21/100
# 80/80 [==============================] - 0s 840us/step - loss: 0.6949
# Epoch 22/100
# 80/80 [==============================] - 0s 665us/step - loss: 0.6947
# Epoch 23/100
# 80/80 [==============================] - 0s 478us/step - loss: 0.6945
# Epoch 24/100
# 80/80 [==============================] - 0s 528us/step - loss: 0.6944
# Epoch 25/100
# 80/80 [==============================] - 0s 521us/step - loss: 0.6943
# Epoch 26/100
# 80/80 [==============================] - 0s 489us/step - loss: 0.6942
# Epoch 27/100
#  1/80 [..............................] - ETA: 0s - loss: 0.6882
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-b2d2f4985be3> in <module>
# ----> 1 model.fit(X, y, batch_size = 5, epochs = 100, verbose = 1)
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
matplotlib.rcParams['figure.figsize'] = (6.0, 4.0)

# %%
def plot_decision_bound(model, X, y):
    amin, bmin = X.min(axis = 0) - 0.1
    amax, bmax = X.max(axis = 0) + 0.1
    
    hticks = np.linspace(amin, amax, 101)   # 민값과 맥스 값을 101개로 쪼갠다
    vticks = np.linspace(bmin, bmax, 101)
    
    aa, bb = np. meshgrid(hticks, vticks)   # 빗금치는 것을 잡아준다.
    ab = np.c_[aa.ravel(), bb.ravel()]
    
    c = model.predict(ab)
    Z = c.reshape(aa.shape)
    
    plt.contourf(aa, bb, Z, cmap = 'bwr', alpha = 0.2)   # 등고선 그리기
    plot_data(plt,X, y)
    return plt

# %%
plot_decision_bound(model, X, y)
plt.title("Logistic Regression")
# Out:
# Text(0.5, 1.0, 'Logistic Regression')

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential
 
np.random.seed(seed)

model = Sequential()

model.add(Dense(6, activation = 'relu', input_dim = 2))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')

model.fit(X, y, batch_size = 5, epochs = 200, verbose = 1)
# Out:
# Epoch 1/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.7083
# Epoch 2/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7038
# Epoch 3/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.7001
# Epoch 4/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6971
# Epoch 5/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6947
# Epoch 6/200
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6923
# Epoch 7/200
# 80/80 [==============================] - 0s 1ms/step - loss: 0.6900
# Epoch 8/200
# 80/80 [==============================] - 0s 726us/step - loss: 0.6877
# Epoch 9/200
# 80/80 [==============================] - 0s 739us/step - loss: 0.6855
# Epoch 10/200
# 80/80 [==============================] - 0s 722us/step - loss: 0.6834
# Epoch 11/200
# 80/80 [==============================] - 0s 732us/step - loss: 0.6812
# Epoch 12/200
# 80/80 [==============================] - 0s 776us/step - loss: 0.6792
# Epoch 13/200
# 80/80 [==============================] - 0s 925us/step - loss: 0.6771
# Epoch 14/200
# 80/80 [==============================] - 0s 950us/step - loss: 0.6750
# Epoch 15/200
# 80/80 [==============================] - 0s 932us/step - loss: 0.6729
# Epoch 16/200
#  1/80 [..............................] - ETA: 0s - loss: 0.6431
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-051816dcdedf> in <module>
#      11 model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')
#      12
# ---> 13 model.fit(X, y, batch_size = 5, epochs = 200, verbose = 1)
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
matplotlib.rcParams['figure.figsize'] = (6.0, 4.0)

plot_decision_bound(model,X,y)
plt.title("Hidden Layer 3(tanh)")
# Out:
# Text(0.5, 1.0, 'Hidden Layer 3(tanh)')

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential
 
np.random.seed(seed)

model = Sequential()

model.add(Dense(1, activation = 'relu', input_dim = 2))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')

model.fit(X, y, batch_size = 5, epochs = 10, verbose = 1)
# Out:
# Epoch 1/10
# 80/80 [==============================] - 0s 985us/step - loss: 0.7060
# Epoch 2/10
# 80/80 [==============================] - 0s 1ms/step - loss: 0.6846
# Epoch 3/10
# 80/80 [==============================] - 0s 998us/step - loss: 0.6746
# Epoch 4/10
# 80/80 [==============================] - 0s 1ms/step - loss: 0.6690
# Epoch 5/10
# 80/80 [==============================] - 0s 982us/step - loss: 0.6659
# Epoch 6/10
# 80/80 [==============================] - 0s 1ms/step - loss: 0.6643
# Epoch 7/10
#  1/80 [..............................] - ETA: 0s - loss: 0.5801
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-71b06004ee6c> in <module>
#      11 model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')
#      12
# ---> 13 model.fit(X, y, batch_size = 5, epochs = 10, verbose = 1)
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     853                 context.async_wait()
#     854               logs = tmp_logs  # No error, now safe to assign to logs.
# --> 855               callbacks.on_train_batch_end(step, logs)
#     856         epoch_logs = copy.copy(logs)
#     857
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     388     if self._should_call_train_batch_hooks:
#     389       logs = self._process_logs(logs)
# --> 390       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     391
#     392   def on_test_batch_begin(self, batch, logs=None):
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     301     delta_t_median = np.median(self._delta_ts[hook_name])
#     302     if (self._delta_t_batch > 0. and
# --> 303         delta_t_median > 0.95 * self._delta_t_batch and delta_t_median > 0.1):
#     304       logging.warning(
#     305           'Method (%s) is slow compared '
#
# KeyboardInterrupt:

# %%
matplotlib.rcParams['figure.figsize'] = (6.0, 4.0)

plot_decision_bound(model,X,y)
plt.title("Hidden Layer 3(tanh)")
# Out:
# Text(0.5, 1.0, 'Hidden Layer 3(tanh)')

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential
 
np.random.seed(seed)

model = Sequential()

model.add(Dense(1, activation = 'relu', input_dim = 2))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')

model.fit(X, y, batch_size = 5, epochs = 1000, verbose = 1)
# Out:
# Epoch 1/1000
# 80/80 [==============================] - 0s 440us/step - loss: 0.6824
# Epoch 2/1000
# 80/80 [==============================] - 0s 524us/step - loss: 0.6813
# Epoch 3/1000
# 80/80 [==============================] - 0s 532us/step - loss: 0.6805
# Epoch 4/1000
# 80/80 [==============================] - 0s 740us/step - loss: 0.6799
# Epoch 5/1000
# 80/80 [==============================] - 0s 786us/step - loss: 0.6794
# Epoch 6/1000
# 80/80 [==============================] - 0s 982us/step - loss: 0.6789
# Epoch 7/1000
# 80/80 [==============================] - 0s 989us/step - loss: 0.6785
# Epoch 8/1000
#  1/80 [..............................] - ETA: 0s - loss: 0.6733
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-c84e535fae14> in <module>
#      11 model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')
#      12
# ---> 13 model.fit(X, y, batch_size = 5, epochs = 1000, verbose = 1)
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
matplotlib.rcParams['figure.figsize'] = (6.0, 4.0)

plot_decision_bound(model,X,y)
plt.title("Hidden Layer 3(tanh)")
# Out:
# Text(0.5, 1.0, 'Hidden Layer 3(tanh)')

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential
 
np.random.seed(seed)

model = Sequential()

model.add(Dense(6, activation = 'relu', input_dim = 2))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')

model.fit(X, y, batch_size = 5, epochs = 1000, verbose = 1)
# Out:
# Epoch 1/1000
# 80/80 [==============================] - 0s 469us/step - loss: 0.6892
# Epoch 2/1000
# 80/80 [==============================] - 0s 550us/step - loss: 0.6858
# Epoch 3/1000
# 80/80 [==============================] - 0s 876us/step - loss: 0.6824
# Epoch 4/1000
# 80/80 [==============================] - 0s 1ms/step - loss: 0.6795
# Epoch 5/1000
# 80/80 [==============================] - 0s 1ms/step - loss: 0.6765
# Epoch 6/1000
# 80/80 [==============================] - 0s 1ms/step - loss: 0.6737
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-5ab82adc1286> in <module>
#      11 model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')
#      12
# ---> 13 model.fit(X, y, batch_size = 5, epochs = 1000, verbose = 1)
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     874           epoch_logs.update(val_logs)
#     875
# --> 876         callbacks.on_epoch_end(epoch, epoch_logs)
#     877         if self.stop_training:
#     878           break
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     363     logs = self._process_logs(logs)
#     364     for callback in self.callbacks:
# --> 365       callback.on_epoch_end(epoch, logs)
#     366
#     367   def on_train_batch_begin(self, batch, logs=None):
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     892
#     893   def on_epoch_end(self, epoch, logs=None):
# --> 894     self._finalize_progbar(logs)
#     895
#     896   def on_test_end(self, logs=None):
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in _finalize_progbar(self, logs)
#     933       self.progbar.target = self.seen
#     934     logs = logs or {}
# --> 935     self.progbar.update(self.seen, list(logs.items()), finalize=True)
#     936
#     937
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/utils/generic_utils.py in update(self, current, values, finalize)
#     654
#     655       sys.stdout.write(info)
# --> 656       sys.stdout.flush()
#     657
#     658     elif self.verbose == 2:
#
# ~/sw/anaconda/lib/python3.7/site-packages/ipykernel/iostream.py in flush(self)
#     349                 self.pub_thread.schedule(evt.set)
#     350                 # and give a timeout to avoid
# --> 351                 if not evt.wait(self.flush_timeout):
#     352                     # write directly to __stderr__ instead of warning because
#     353                     # if this is happening sys.stderr may be the problem.
#
# ~/sw/anaconda/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/sw/anaconda/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
matplotlib.rcParams['figure.figsize'] = (6.0, 4.0)

plot_decision_bound(model,X,y)
plt.title("Hidden Layer 3(tanh)")
# Out:
# Text(0.5, 1.0, 'Hidden Layer 3(tanh)')

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential
 
np.random.seed(seed)

model = Sequential()

model.add(Dense(256, activation = 'relu', input_dim = 2))
model.add(Dense(128, activation = 'tanh', input_dim = 2))
model.add(Dense(64, activation = 'tanh', input_dim = 2))
model.add(Dense(32, activation = 'tanh', input_dim = 2))
model.add(Dense(16, activation = 'tanh', input_dim = 2))
model.add(Dense(8, activation = 'tanh', input_dim = 2))
model.add(Dense(4, activation = 'tanh', input_dim = 2))
model.add(Dense(2, activation = 'tanh', input_dim = 2))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')

model.fit(X, y, batch_size = 5, epochs = 1000, verbose = 1)
# Out:
# Epoch 1/1000
# 80/80 [==============================] - 0s 674us/step - loss: 0.6858
# Epoch 2/1000
# 80/80 [==============================] - 0s 648us/step - loss: 0.6053
# Epoch 3/1000
# 80/80 [==============================] - 0s 1ms/step - loss: 0.4872
# Epoch 4/1000
# 80/80 [==============================] - 0s 613us/step - loss: 0.3750
# Epoch 5/1000
# 80/80 [==============================] - 0s 595us/step - loss: 0.2955
# Epoch 6/1000
# 80/80 [==============================] - 0s 614us/step - loss: 0.2794
# Epoch 7/1000
# 80/80 [==============================] - 0s 608us/step - loss: 0.2372
# Epoch 8/1000
# 80/80 [==============================] - 0s 595us/step - loss: 0.2210
# Epoch 9/1000
# 80/80 [==============================] - 0s 615us/step - loss: 0.1984
# Epoch 10/1000
# 80/80 [==============================] - 0s 618us/step - loss: 0.1919
# Epoch 11/1000
# 80/80 [==============================] - 0s 617us/step - loss: 0.1946
# Epoch 12/1000
# 80/80 [==============================] - 0s 616us/step - loss: 0.2064
# Epoch 13/1000
# 80/80 [==============================] - 0s 623us/step - loss: 0.2107
# Epoch 14/1000
# 80/80 [==============================] - 0s 610us/step - loss: 0.1673
# Epoch 15/1000
# 80/80 [==============================] - 0s 619us/step - loss: 0.1687
# Epoch 16/1000
# 80/80 [==============================] - 0s 617us/step - loss: 0.2164
# Epoch 17/1000
# 80/80 [==============================] - 0s 637us/step - loss: 0.1900
# Epoch 18/1000
# 80/80 [==============================] - 0s 616us/step - loss: 0.1526
# Epoch 19/1000
# 80/80 [==============================] - 0s 605us/step - loss: 0.1629
# Epoch 20/1000
# 80/80 [==============================] - 0s 760us/step - loss: 0.1601
# Epoch 21/1000
# 80/80 [==============================] - 0s 895us/step - loss: 0.1583
# Epoch 22/1000
# 80/80 [==============================] - 0s 912us/step - loss: 0.1402
# Epoch 23/1000
# 80/80 [==============================] - 0s 917us/step - loss: 0.1389
# Epoch 24/1000
#  1/80 [..............................] - ETA: 0s - loss: 0.0551
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-14d503ae60da> in <module>
#      18 model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')
#      19
# ---> 20 model.fit(X, y, batch_size = 5, epochs = 1000, verbose = 1)
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
matplotlib.rcParams['figure.figsize'] = (6.0, 4.0)

plot_decision_bound(model,X,y)
plt.title("Hidden Layer 3(tanh)")
# Out:
# Text(0.5, 1.0, 'Hidden Layer 3(tanh)')

# %%
import pandas as pd

data = pd.read_csv('Applied-Deep-Learning-with-Keras/Lesson02/bank_data_feats.csv', index_col = 0)
y = pd.read_csv('Applied-Deep-Learning-with-Keras/Lesson02/bank_data_target.csv', index_col = 0)

X = data

# %%
print('Num of Datast = ', data.shape[0])
print('Num of Features = ', data.shape[1])
print(y.shape)
# Out:
# Num of Datast =  4521
# Num of Features =  32
# (4521, 1)

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential
 
def build_model():
    model = Sequential()

    model.add(Dense(16, input_dim = X.shape[1], activation = 'relu'))
    model.add(Dense(8, activation = 'relu', input_dim = 2))
    model.add(Dense(1, activation = 'sigmoid', input_dim = 2))

    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

    return model

# %%
import numpy as np
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score

# %%
seed = 1

np.random.seed(seed)

# %%
n_flods = 5
epochs = 300
batch_size = 5
# 분류 작업시 분류기를 생성자
classifier = KerasClassifier(
    # 실질적으로 분류르 수행하는데 사용할 모델을 만드는 함수
    build_fn = build_model,    # 제일 중요함
    # 몇 회 반복을 할 것 인가
    epochs = epochs,
    batch_size = batch_size, 
    verbose = 1)

# %%
kfold = StratifiedKFold(n_splits = n_flods, shuffle = True, random_state = seed)

# %%
results = cross_val_score(classifier, X, y, cv = kfold)
# Out:
# Epoch 1/300
# 138/724 [====>.........................] - ETA: 0s - loss: 9.7091 - accuracy: 0.7841
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-79b717ad67b4> in <module>
# ----> 1 results = cross_val_score(classifier, X, y, cv = kfold)
#
# ~/sw/anaconda/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     388                                 fit_params=fit_params,
#     389                                 pre_dispatch=pre_dispatch,
# --> 390                                 error_score=error_score)
#     391     return cv_results['test_score']
#     392
#
# ~/sw/anaconda/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     234             return_times=True, return_estimator=return_estimator,
#     235             error_score=error_score)
# --> 236         for train, test in cv.split(X, y, groups))
#     237
#     238     zipped_scores = list(zip(*scores))
#
# ~/sw/anaconda/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# ~/sw/anaconda/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~/sw/anaconda/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~/sw/anaconda/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~/sw/anaconda/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~/sw/anaconda/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~/sw/anaconda/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~/sw/anaconda/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     513             estimator.fit(X_train, **fit_params)
#     514         else:
# --> 515             estimator.fit(X_train, y_train, **fit_params)
#     516
#     517     except Exception as e:
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     221       raise ValueError('Invalid shape for y: ' + str(y.shape))
#     222     self.n_classes_ = len(self.classes_)
# --> 223     return super(KerasClassifier, self).fit(x, y, **kwargs)
#     224
#     225   def predict(self, x, **kwargs):
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     164     fit_args.update(kwargs)
#     165
# --> 166     history = self.model.fit(x, y, **fit_args)
#     167
#     168     return history
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/sw/anaconda/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
for f in range(n_flods):
    print("Accuracy at fold", f + 1 , "=", results[f])

print("")
print("Final Cross Valid Test Accuracy", results.mean())
print("Standard Deviation if Final Test Accuracy : ", results.std())
# Out:
# Accuracy at fold 1 = [0.87955803 0.88495576 0.8738938  0.88163716 0.86946905]
# Accuracy at fold 2 = [0.8110497  0.88495576 0.88495576 0.88827431 0.88495576]
# Accuracy at fold 3 = [0.88176793 0.80862832 0.85951328 0.88495576 0.88495576]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-ca3077a09859> in <module>
#       1 for f in range(n_flods):
# ----> 2     print("Accuracy at fold", f + 1 , "=", results[f])
#       3
#       4 print("")
#       5 print("Final Cross Valid Test Accuracy", results.mean())
#
# IndexError: list index out of range

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential

import numpy as np
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score

# %%
def model_build1(activation = 'relu', optimizer = 'adam'):
    model = Sequential()
    
    model.add(Dense(8, input_dim = X.shape[1], activation = activation))
    model.add(Dense(8, activation = activation))
    model.add(Dense(8, activation = activation))    
    model.add(Dense(1, activation = 'sigmoid'))
    model.compile(
        loss = 'binary_crossentropy', 
        optimizer = optimizer, 
        metrics = ['accuracy'])
    return model

def model_build2(activation = 'relu', optimizer = 'adam'):
    model = Sequential()
    
    model.add(Dense(16, input_dim = X.shape[1], activation = activation))
    model.add(Dense(8, activation = activation))
    model.add(Dense(4, activation = activation))    
    model.add(Dense(1, activation = 'sigmoid'))
    model.compile(
        loss = 'binary_crossentropy', 
        optimizer = optimizer, 
        metrics = ['accuracy'])
    return model

def model_build3(activation = 'relu', optimizer = 'adam'):
    model = Sequential()
    
    model.add(Dense(8, input_dim = X.shape[1], activation = activation))
    model.add(Dense(4, activation = activation))   
    model.add(Dense(1, activation = 'sigmoid'))
    model.compile(
        loss = 'binary_crossentropy', 
        optimizer = optimizer, 
        metrics = ['accuracy'])
    return model

# %%
seed = 1
n_flods = 5
batch_size = 5
epochs = 1

results = []

models = [model_build1, model_build2, model_build3]

# %%
for idx in range(len(models)):
    classifier = KerasClassifier(
        build_fn = models[idx],
        epochs = epochs,
        batch_size = batch_size,
        verbose = 1
    )
    kfold = StratifiedKFold(
        n_splits=n_flods, 
        shuffle=True, 
        random_state = seed)
    
    result = cross_val_score(classifier, X, y, cv = kfold)

    results.append(result)
# Out:
# 724/724 [==============================] - 1s 2ms/step - loss: 2.2750 - accuracy: 0.7998
# 181/181 [==============================] - 0s 451us/step - loss: 1.1218 - accuracy: 0.8796
# 724/724 [==============================] - 1s 2ms/step - loss: 0.7440 - accuracy: 0.8438
# 181/181 [==============================] - 0s 435us/step - loss: 0.4990 - accuracy: 0.8850
# 724/724 [==============================] - 1s 2ms/step - loss: 0.8773 - accuracy: 0.8045
# 181/181 [==============================] - 0s 488us/step - loss: 0.4417 - accuracy: 0.8739
# 724/724 [==============================] - 1s 2ms/step - loss: 2.6560 - accuracy: 0.8640
# 181/181 [==============================] - 0s 441us/step - loss: 0.4480 - accuracy: 0.8816
# 724/724 [==============================] - 1s 2ms/step - loss: 1.8694 - accuracy: 0.8142
# 181/181 [==============================] - 0s 476us/step - loss: 0.5114 - accuracy: 0.8695
# 724/724 [==============================] - 1s 1ms/step - loss: 2.6932 - accuracy: 0.8078
# 181/181 [==============================] - 0s 449us/step - loss: 1.0190 - accuracy: 0.8110
# 724/724 [==============================] - 1s 2ms/step - loss: 0.8125 - accuracy: 0.8233
# 181/181 [==============================] - 0s 511us/step - loss: 0.4992 - accuracy: 0.8850
# 724/724 [==============================] - 1s 1ms/step - loss: 4.7396 - accuracy: 0.8197
# 181/181 [==============================] - 0s 483us/step - loss: 0.6091 - accuracy: 0.8850
# 724/724 [==============================] - 1s 1ms/step - loss: 1.2542 - accuracy: 0.8366
# 181/181 [==============================] - 0s 576us/step - loss: 0.8839 - accuracy: 0.8883
# 724/724 [==============================] - 1s 1ms/step - loss: 3.2392 - accuracy: 0.8294
# 181/181 [==============================] - 0s 566us/step - loss: 0.5473 - accuracy: 0.8850
# 724/724 [==============================] - 1s 2ms/step - loss: 9.0468 - accuracy: 0.8711
# 181/181 [==============================] - 0s 451us/step - loss: 0.9454 - accuracy: 0.8818
# 724/724 [==============================] - 1s 2ms/step - loss: 83.9713 - accuracy: 0.3788
# 181/181 [==============================] - 0s 536us/step - loss: 0.6929 - accuracy: 0.8086
# 724/724 [==============================] - 1s 2ms/step - loss: 56.8880 - accuracy: 0.6832
# 181/181 [==============================] - 0s 438us/step - loss: 0.9136 - accuracy: 0.8595
# 724/724 [==============================] - 1s 2ms/step - loss: 3.5098 - accuracy: 0.8352
# 181/181 [==============================] - 0s 411us/step - loss: 0.7847 - accuracy: 0.8850
# 724/724 [==============================] - 1s 1ms/step - loss: 0.5960 - accuracy: 0.8789
# 181/181 [==============================] - 0s 465us/step - loss: 0.5146 - accuracy: 0.8850

# %%
for idx in range(len(models)):
    print("Model", idx + 1, "Test Acccuracy = ", results[idx].mean())
# Out:
# Model 1 Test Acccuracy =  0.8779027581214904
# Model 2 Test Acccuracy =  0.8708382606506347
# Model 3 Test Acccuracy =  0.8639642119407653

# %%
optimizers = ['rmsprop', 'adam', 'sgd']
activations = ['relu', 'tanh']

for opt in range(len(optimizers)):
    for activie in range(len(activations)):
        optimizer = optimizers[opt]
        activiation = activations[active]
        
        classifier = KerasClassifier(
            build_fn=model_build1,
            epochs = 300,
            batch_size = 5,
            verbose = 1
        )
        
        kfold = StratifiedKFold(
            n_splits=n_flods,
            shuffle=True,
            random_state =seed
        )
        
        result = cross_val_score(classifier, X, y, cv = kfold)
        results.append(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-1126cd4c345c> in <module>
#       5     for activie in range(len(activations)):
#       6         optimizer = optimizers[opt]
# ----> 7         activiation = activations[active]
#       8
#       9         classifier = KerasClassifier(
#
# NameError: name 'active' is not defined

# %%
c = 0
for opt in range(len(optimizers)):
    for active in range(len(activations)):
        print("activation = ", activations[active])
        print("optimizer = ", optimizers[opt])
        print("Test Accuracy = ", results[c].mean())
# Out:
# activation =  relu
# optimizer =  rmsprop
# Test Accuracy =  0.8818865299224854
# activation =  tanh
# optimizer =  rmsprop
# Test Accuracy =  0.8818865299224854
# activation =  relu
# optimizer =  adam
# Test Accuracy =  0.8818865299224854
# activation =  tanh
# optimizer =  adam
# Test Accuracy =  0.8818865299224854
# activation =  relu
# optimizer =  sgd
# Test Accuracy =  0.8818865299224854
# activation =  tanh
# optimizer =  sgd
# Test Accuracy =  0.8818865299224854

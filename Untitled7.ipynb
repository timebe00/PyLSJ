# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import matplotlib.patches as mpatches
from sklearn.datasets import make_blobs, make_circles
from keras.layers import Dense, Activation
from keras.models import Sequential

# %%
# 1번

# %%
def plot_data(pl, X, y):
    pl.plot(X[y == 0, 0], X[y == 0, 1], 'ob', alpha = 0.5)
    pl.plot(X[y == 1, 0], X[y == 1, 1], 'xr', alpha = 0.5)
    pl.legend(['0', '1'])
    return pl

X, y = make_circles(
    n_samples = 400, 
    factor = 0.6, 
    noise = 0.1, 
    random_state = 42
)

# %%
pl = plot_data(plt, X, y)
pl.show()

# %%
seed = 1
np.random.seed(seed)

model = Sequential()
model.add(Dense(1, activation = 'sigmoid', input_dim = 2))
model.compile(optimizer = 'sgd', loss = 'binary_crossentropy', metrics=['accuracy'])
history = model.fit(X, y, batch_size = 20, epochs = 100, verbose = 1)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 489us/step - loss: 0.7738 - accuracy: 0.4950
# Epoch 2/100
# 20/20 [==============================] - 0s 471us/step - loss: 0.7715 - accuracy: 0.4950
# Epoch 3/100
# 20/20 [==============================] - 0s 462us/step - loss: 0.7692 - accuracy: 0.4950
# Epoch 4/100
# 20/20 [==============================] - 0s 486us/step - loss: 0.7670 - accuracy: 0.4925
# Epoch 5/100
# 20/20 [==============================] - 0s 476us/step - loss: 0.7648 - accuracy: 0.4975
# Epoch 6/100
# 20/20 [==============================] - 0s 463us/step - loss: 0.7627 - accuracy: 0.4975
# Epoch 7/100
# 20/20 [==============================] - 0s 483us/step - loss: 0.7606 - accuracy: 0.4975
# Epoch 8/100
# 20/20 [==============================] - 0s 469us/step - loss: 0.7586 - accuracy: 0.4975
# Epoch 9/100
# 20/20 [==============================] - 0s 486us/step - loss: 0.7568 - accuracy: 0.4975
# Epoch 10/100
# 20/20 [==============================] - 0s 500us/step - loss: 0.7548 - accuracy: 0.4925
# Epoch 11/100
# 20/20 [==============================] - 0s 472us/step - loss: 0.7530 - accuracy: 0.4975
# Epoch 12/100
# 20/20 [==============================] - 0s 455us/step - loss: 0.7511 - accuracy: 0.4975
# Epoch 13/100
# 20/20 [==============================] - 0s 474us/step - loss: 0.7494 - accuracy: 0.4975
# Epoch 14/100
# 20/20 [==============================] - 0s 494us/step - loss: 0.7477 - accuracy: 0.4975
# Epoch 15/100
# 20/20 [==============================] - 0s 471us/step - loss: 0.7460 - accuracy: 0.4975
# Epoch 16/100
# 20/20 [==============================] - 0s 679us/step - loss: 0.7445 - accuracy: 0.4975
# Epoch 17/100
# 20/20 [==============================] - 0s 503us/step - loss: 0.7429 - accuracy: 0.4975
# Epoch 18/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7414 - accuracy: 0.4975
# Epoch 19/100
# 20/20 [==============================] - 0s 437us/step - loss: 0.7399 - accuracy: 0.4950
# Epoch 20/100
# 20/20 [==============================] - 0s 490us/step - loss: 0.7385 - accuracy: 0.4975
# Epoch 21/100
# 20/20 [==============================] - 0s 442us/step - loss: 0.7371 - accuracy: 0.4950
# Epoch 22/100
# 20/20 [==============================] - 0s 437us/step - loss: 0.7357 - accuracy: 0.5000
# Epoch 23/100
# 20/20 [==============================] - 0s 468us/step - loss: 0.7344 - accuracy: 0.5000
# Epoch 24/100
# 20/20 [==============================] - 0s 470us/step - loss: 0.7331 - accuracy: 0.4975
# Epoch 25/100
# 20/20 [==============================] - 0s 570us/step - loss: 0.6983 - accuracy: 0.4900
# Epoch 88/100
# 20/20 [==============================] - 0s 576us/step - loss: 0.6981 - accuracy: 0.4925
# Epoch 89/100
# 20/20 [==============================] - 0s 595us/step - loss: 0.6979 - accuracy: 0.4900
# Epoch 90/100
# 20/20 [==============================] - 0s 588us/step - loss: 0.6977 - accuracy: 0.4900
# Epoch 91/100
# 20/20 [==============================] - 0s 557us/step - loss: 0.6976 - accuracy: 0.4925
# Epoch 92/100
# 20/20 [==============================] - 0s 530us/step - loss: 0.6974 - accuracy: 0.4925
# Epoch 93/100
# 20/20 [==============================] - 0s 570us/step - loss: 0.6973 - accuracy: 0.4950
# Epoch 94/100
# 20/20 [==============================] - 0s 586us/step - loss: 0.6972 - accuracy: 0.4900
# Epoch 95/100
# 20/20 [==============================] - 0s 593us/step - loss: 0.6971 - accuracy: 0.4875
# Epoch 96/100
# 20/20 [==============================] - 0s 591us/step - loss: 0.6970 - accuracy: 0.4875
# Epoch 97/100
# 20/20 [==============================] - 0s 576us/step - loss: 0.6968 - accuracy: 0.4900
# Epoch 98/100
# 20/20 [==============================] - 0s 579us/step - loss: 0.6967 - accuracy: 0.4900
# Epoch 99/100
# 20/20 [==============================] - 0s 573us/step - loss: 0.6966 - accuracy: 0.4950
# Epoch 100/100
# 20/20 [==============================] - 0s 550us/step - loss: 0.6965 - accuracy: 0.4900

# %%
plt.plot(history.history['lose'])
plt.title("Line")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
matplotlib.rcParams['figure.figsize'] = (6.0, 4.0)
def plot_decision_bound(model, X, y):
    amin, bmin = X.min(axis = 0) - 0.1
    amax, bmax = X.max(axis = 0) + 0.1
    
    hticks = np.linspace(amin, amax, 101)
    vticks = np.linspace(bmin, bmax, 101)
    
    aa, bb = np.meshgrid(hticks, vticks)
    ab = np.c_[aa.ravel(), bb.ravel()]
    
    c = model.predict(ab)
    Z = c.reshape(aa.shape)
    
    plt.contourf(aa, bb, Z, cmap = 'bwr', alpha = 0.2)
    plot_data(plt, X, y)
    return plt
plt.title("Logistic Regression")
plot_decision_bound(model, X, y)
# Out:
# <module 'matplotlib.pyplot' from '/home/bitai/sw/anaconda/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
# 2번

# %%
np.random.seed(seed)

model = Sequential()

model.add(Dense(256, activation = 'tanh', input_dim = 2))
model.add(Dense(128, activation = 'tanh'))
model.add(Dense(96, activation = 'tanh'))
model.add(Dense(64, activation = 'tanh'))
model.add(Dense(32, activation = 'tanh'))
model.add(Dense(32, activation = 'tanh'))
model.add(Dense(16, activation = 'tanh'))
model.add(Dense(8, activation = 'tanh'))
model.add(Dense(1, activation = 'tanh'))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(optimizer = 'sgd', loss = 'binary_crossentropy', metrics=['accuracy'])
history = model.fit(X, y, batch_size = 5, epochs = 10, verbose = 1)
# Out:
# Epoch 1/10
# 80/80 [==============================] - 0s 714us/step - loss: 0.6935 - accuracy: 0.4950
# Epoch 2/10
# 80/80 [==============================] - 0s 639us/step - loss: 0.6934 - accuracy: 0.4975
# Epoch 3/10
# 80/80 [==============================] - 0s 660us/step - loss: 0.6934 - accuracy: 0.5250
# Epoch 4/10
# 80/80 [==============================] - 0s 637us/step - loss: 0.6933 - accuracy: 0.4825
# Epoch 5/10
# 80/80 [==============================] - 0s 641us/step - loss: 0.6933 - accuracy: 0.4900
# Epoch 6/10
# 80/80 [==============================] - 0s 625us/step - loss: 0.6933 - accuracy: 0.5175
# Epoch 7/10
# 80/80 [==============================] - 0s 634us/step - loss: 0.6931 - accuracy: 0.5300
# Epoch 8/10
# 80/80 [==============================] - 0s 642us/step - loss: 0.6931 - accuracy: 0.5425
# Epoch 9/10
# 80/80 [==============================] - 0s 650us/step - loss: 0.6928 - accuracy: 0.5275
# Epoch 10/10
# 80/80 [==============================] - 0s 657us/step - loss: 0.6927 - accuracy: 0.5625

# %%
plot_decision_bound(model, X, y)
plt.title("Hidden Layer")
# Out:
# Text(0.5, 1.0, 'Hidden Layer')

# %%
plt.plot(history.history['accuracy'])
plt.title("Line")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# 3, 4, 5, 6번

# %%
from flask import Flask, jsonify

import requests
import json
from flask_restful import Resource, Api, reqparse

# %%
app = Flask(__name__)
api = Api(app)

# localhost:8080/dataServer로 요청을 하면
# 아래 함수가 동작을 한다는 의미!
@app.route('/dataServer')
def PythonServerResponse():
    print("It's operate")
    summary = {'J' : history.history}
    return jsonify(summary)

app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [10/Jul/2020 15:30:42] "GET /dataServer HTTP/1.1" 200 -
# It's operate
# 127.0.0.1 - - [10/Jul/2020 15:36:00] "GET /dataServer HTTP/1.1" 200 -
# It's operate

# %%
7번

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import matplotlib.patches as mpatches
from sklearn.datasets import make_blobs, make_circles
from keras.layers import Dense, Activation
from keras.models import Sequential
import pandas as pd 
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score

# %%
def plot_data(pl, X, y):
    pl.plot(X[y == 0, 0], X[y == 0, 1], 'ob', alpha = 0.5)
    pl.plot(X[y == 1, 0], X[y == 1, 1], 'xr', alpha = 0.5)
    pl.legend(['0', '1'])
    return pl

# %%
X, y = make_circles(n_samples = 400, factor = 0.6, noise = 0.1, random_state = 42)
pl = plot_data(plt, X, y)
pl.show()

# %%
def model_build():
    model = Sequential()
        
    model.add(Dense(256, activation = 'tanh', input_dim = X.shape[1]))
    model.add(Dense(128, activation = 'tanh'))
    model.add(Dense(64, activation = 'tanh'))
    model.add(Dense(32, activation = 'tanh'))
    model.add(Dense(16, activation = 'tanh'))
    model.add(Dense(8, activation = 'tanh'))
    model.add(Dense(4, activation = 'tanh'))
    model.add(Dense(2, activation = 'tanh'))
    model.add(Dense(1, activation = 'sigmoid'))

    
    model.compile(
        loss = 'binary_crossentropy', 
        optimizer = optimizer, 
        metrics = ['accuracy'])
    
    return model

# %%
seed = 1
n_flods = 5
batch_size = 5
epochs = 1

results = []

# %%
optimizer = ['adam']
activations = ['tanh']
classifier = KerasClassifier(
    build_fn = model_build1,
    epochs = 300,
    batch_size = 5,
    verbose = 1
)
        
kfold = StratifiedKFold(
    n_splits = n_folds,
    shuffle = True,
    random_state = seed
)
        
result = cross_val_score(classifier, X, y, cv = kfold)

results.append(result)

# %%
classifier = KerasClassifier(
    build_fn = model_build,
    epochs = epochs,
    batch_size = batch_size,
    verbose = 1
)
kfold = StratifiedKFold(
    n_splits=n_flods, 
    shuffle=True, 
    random_state = seed)
    
result = cross_val_score(classifier, X, y, cv = kfold)
    
results.append(result)
